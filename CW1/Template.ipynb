# %% [markdown]
# # Coursework 1 - Articial Intelligence and Machine Learning
# # Student Name:
# # Student Email:
#
# I confirm that the material contained within the submitted coursework is all my own work unless otherwise stated below.
#
# ---

# %% [markdown]
# Your text here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from scipy.stats import boxcox
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
from sklearn import metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical, normalize
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix  
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score
import warnings
warnings.filterwarnings("ignore")
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
tf.debugging.set_log_device_placement(True)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print(tf.config.list_physical_devices())
# Out:
# 2022-11-03 16:00:08.900978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 1 Physical GPUs, 1 Logical GPUs
# Num GPUs Available:  1
# Num CPUs Available:  1
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2022-11-03 16:00:09.976823: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-03 16:00:09.977636: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-03 16:00:09.990075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:09.990219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0c:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.67GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-11-03 16:00:09.990238: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-03 16:00:10.018839: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-03 16:00:10.018943: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-03 16:00:10.036131: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-03 16:00:10.039992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-03 16:00:10.071403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-03 16:00:10.076000: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-03 16:00:10.129882: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-03 16:00:10.130118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:10.130292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:10.130357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-03 16:00:10.131165: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-03 16:00:10.132457: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-03 16:00:10.132626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:10.132719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0c:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.67GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-11-03 16:00:10.132772: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-03 16:00:10.132789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-11-03 16:00:10.132799: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-11-03 16:00:10.132808: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-11-03 16:00:10.132817: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-11-03 16:00:10.132825: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-11-03 16:00:10.132835: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-11-03 16:00:10.132845: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-11-03 16:00:10.132892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:10.132993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:10.133051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-11-03 16:00:10.133481: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-11-03 16:00:13.420839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-03 16:00:13.420858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-11-03 16:00:13.420863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-11-03 16:00:13.421502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:13.421634: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:13.421736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-03 16:00:13.421812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21584 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6)

# %%
#load data
df = pd.read_csv('/home/antony/Documents/AIML#/CW1/bike-dataset/bike-dataset/bike-dataset hour.csv')
features = df.columns
# print(features)
# print(df.head())
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  15595.000000  15595.000000
# mean       0.028770      3.003683      1.425283      0.496451      0.475300
# std        0.167165      2.005771      0.639357      0.192580      0.171928
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        0.000000      1.000000      1.000000      0.340000      0.333300
# 50%        0.000000      3.000000      1.000000      0.500000      0.484800
# 75%        0.000000      5.000000      2.000000      0.660000      0.621200
# max        1.000000      6.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed        casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098     35.676218    153.786869    189.463088
# std        0.192930      0.122340     49.305030    151.357286    181.387599
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        0.780000      0.253700     48.000000    220.000000    281.000000
# max        1.000000      0.850700    367.000000    886.000000    977.000000

# %%
from dataprep.eda import create_report
report = create_report(df)

report.save('report.html')
# Out:
#   0%|          | 0/2618 [00:00<?, ?it/s]
# Report has been saved to report.html!

# %% [markdown]
# #check for duplicated data

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicated rows: ", duplicate_rows_df.shape)
print (duplicate_rows_df)
# Out:
# number of duplicated rows:  (0, 17)
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
df2 = df.set_index('instant')
# df2.describe()
df2.head(10)
# Out:
#         instant      dteday  yr  mnth  hr  holiday  weekday workingday  \
# season
# 1             1  2011-01-01   0     1   0        0        6         No
# 1             2  2011-01-01   0     1   1        0        6         No
# 1             3  2011-01-01   0     1   2        0        6         No
# 1             4  2011-01-01   0     1   3        0        6         No
# 1             5  2011-01-01   0     1   4        0        6         No
# 1             6  2011-01-01   0     1   5        0        6         No
# 1             7  2011-01-01   0     1   6        0        6         No
# 1             8  2011-01-01   0     1   7        0        6         No
# 1             9  2011-01-01   0     1   8        0        6         No
# 1            10  2011-01-01   0     1   9        0        6         No
#
#         weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# season
# 1                1  0.24  0.2879  0.81     0.0000       3          13   16
# 1                1  0.22  0.2727  0.80     0.0000       8          32   40
# 1                1  0.22  0.2727  0.80     0.0000       5          27   32
# 1                1  0.24  0.2879  0.75     0.0000       3          10   13
# 1                1  0.24  0.2879  0.75     0.0000       0           1    1
# 1                2  0.24  0.2576  0.75     0.0896       0           1    1
# 1                1  0.22  0.2727  0.80     0.0000       2           0    2
# 1                1  0.20  0.2576  0.86     0.0000       1           2    3
# 1                1  0.24  0.2879  0.75     0.0000       1           7    8
# 1                1  0.32  0.3485  0.76     0.0000       8           6   14

# %%
print(df2.dtypes)
df['instant'].value_counts()
# Out:
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday     object
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object
# 1        1
# 11592    1
# 11578    1
# 11579    1
# 11580    1
#         ..
# 5799     1
# 5800     1
# 5801     1
# 5802     1
# 17379    1
# Name: instant, Length: 17379, dtype: int64

# %%
dfplot = plot(df)
# Out:
#   0%|          | 0/860 [00:00<?, ?it/s]

# %% [markdown]
# ---
#
# This cell goes to the very bottom of your submitted notebok.
# You are requried to link the sources and web-links that you have used for various parts of this coursework.
#
# Write them sources used in the following format similar to the first examle in the sources list below :
#
#     - what you have used them for : web-link
#
# Sources:
#
# - Implement a recurrent neural network : https://peterroelants.github.io/posts/rnn-implementation-part01/
